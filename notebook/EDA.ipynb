# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load data into DataFrame
data = pd.read_csv(r'C:\Users\salma elyagoubi\TSA\TSA\data\filtered_sensor.csv', sep=',')

# Display basic information about the data
data.info()

# Display the first few rows of the data
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204557 entries, 0 to 204556
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      204557 non-null  int64
#  1   timestamp       204557 non-null  object
#  2   sensor_00       194352 non-null  float64
#  3   sensor_01       204191 non-null  float64
#  4   sensor_02       204541 non-null  float64
#  5   sensor_03       204541 non-null  float64
#  6   sensor_04       204541 non-null  float64
#  7   sensor_05       204541 non-null  float64
#  8   sensor_06       199762 non-null  float64
#  9   sensor_07       199109 non-null  float64
#  10  sensor_08       199453 non-null  float64
#  11  sensor_09       199965 non-null  float64
#  12  sensor_10       204541 non-null  float64
#  13  sensor_11       204541 non-null  float64
#  14  sensor_12       204541 non-null  float64
#  15  sensor_13       204541 non-null  float64
# ...

# %%
# Merge 'BROKEN' and 'RECOVERING' statuses into a single 'BROKEN' category
data['machine_status'] = data['machine_status'].replace({'RECOVERING': 'BROKEN'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204557 entries, 0 to 204556
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      204557 non-null  int64
#  1   timestamp       204557 non-null  object
#  2   sensor_00       194352 non-null  float64
#  3   sensor_01       204191 non-null  float64
#  4   sensor_02       204541 non-null  float64
#  5   sensor_03       204541 non-null  float64
#  6   sensor_04       204541 non-null  float64
#  7   sensor_05       204541 non-null  float64
#  8   sensor_06       199762 non-null  float64
#  9   sensor_07       199109 non-null  float64
#  10  sensor_08       199453 non-null  float64
#  11  sensor_09       199965 non-null  float64
#  12  sensor_10       204541 non-null  float64
#  13  sensor_11       204541 non-null  float64
#  14  sensor_12       204541 non-null  float64
#  15  sensor_13       204541 non-null  float64
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0      sensor_00      sensor_01      sensor_02  \
# count  204557.000000  194352.000000  204191.000000  204541.000000
# mean   102278.000000       2.365821      47.441533      50.805689
# std     59050.663845       0.427689       3.349820       3.789427
# min         0.000000       0.000000       0.000000      33.159720
# 25%     51139.000000       2.444734      46.180550      50.303820
# 50%    102278.000000       2.456539      47.960070      51.649300
# 75%    153417.000000       2.499826      49.305550      52.821180
# max    204556.000000       2.549016      56.727430      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  204541.000000  204541.000000  204541.000000  199762.000000
# mean       43.643212     587.579595      73.376885      13.393828
# std         2.458106     148.997810      17.872356       2.210346
# min        31.640620       2.798032       0.000000       0.014468
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data into DataFrame
data = pd.read_csv(r'C:\Users\salma elyagoubi\TSA\TSA\data\filtered_sensor.csv', sep=',')

# Merge 'BROKEN' and 'RECOVERING' statuses into a single 'BROKEN' category
data['machine_status'] = data['machine_status'].replace({'RECOVERING': 'BROKEN'})

# Calculate percentage of each machine status
status_counts = data['machine_status'].value_counts(normalize=True) * 100
print("Percentage of each machine status:")
print(status_counts)

# Define the selected sensors
selected_sensors = ['sensor_04', 'sensor_10', 'sensor_20']

# Function to identify anomalies
def identify_anomalies(sensor_data, threshold=3):
    mean = sensor_data.mean()
    std = sensor_data.std()
    anomalies = (sensor_data - mean).abs() > threshold * std
    return anomalies
# Out:
# Percentage of each machine status:
# machine_status
# NORMAL    92.919929
# BROKEN     7.080071
# Name: proportion, dtype: float64

# %%
def calculate_sensor_means(data, sensors):
    """
    Calculate the mean for each sensor in the data.
    
    Parameters:
        data (pd.DataFrame): The input data frame containing sensor data.
        sensors (list): List of sensor column names.
        
    Returns:
        dict: Dictionary with sensor names as keys and their mean values as values.
    """
    means = {}
    for sensor in sensors:
        means[sensor] = data[sensor].mean()
    return means

def plot_anomalies(data, sensors, threshold=3):
    """
    Plot sensor data and highlight anomalies based on the mean and specified threshold.
    
    Parameters:
        data (pd.DataFrame): The input data frame containing sensor data and timestamps.
        sensors (list): List of sensor column names to plot.
        threshold (float): The threshold multiplier for detecting anomalies (default is 3).
    """
    fig, axs = plt.subplots(len(sensors), 1, figsize=(15, 5 * len(sensors)))

    for i, sensor in enumerate(sensors):
        sensor_data = data[sensor]
        mean_value = sensor_data.mean()
        std_dev = sensor_data.std()
        
        # Identify anomalies
        anomalies = (sensor_data - mean_value).abs() > threshold * std_dev
        
        # Plotting the sensor data
        axs[i].plot(data['timestamp'], sensor_data, label=sensor, color='blue')
        axs[i].scatter(data['timestamp'][anomalies], sensor_data[anomalies], color='red', label='Anomaly')
        
        axs[i].set_title(f'{sensor} with Anomalies')
        axs[i].set_xlabel('Timestamp')
        axs[i].set_ylabel('Value')
        axs[i].legend()
    
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 15
#      12     axs[i].set_ylabel('Value')
#      13     axs[i].legend()
# ---> 15 plt.tight_layout()
#      16 plt.show()
#
# File c:\Users\salma elyagoubi\miniconda3\envs\ml\lib\site-packages\matplotlib\pyplot.py:2599, in tight_layout(pad, h_pad, w_pad, rect)
#    2591 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2592 def tight_layout(
#    2593     *,
#    (...)
#    2597     rect: tuple[float, float, float, float] | None = None,
#    2598 ) -> None:
# -> 2599     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File c:\Users\salma elyagoubi\miniconda3\envs\ml\lib\site-packages\matplotlib\figure.py:3540, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3538 previous_engine = self.get_layout_engine()
#    3539 self.set_layout_engine(engine)
# ...
